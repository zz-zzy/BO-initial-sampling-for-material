# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from collections import Counter

def find_duplicate_rows(X):
    Z = X
    # 将数组中的每一行表示为元组，并将这些元组存储在列表中
    row_tuples = [tuple(row) for row in Z]

    # 使用Python的collections.Counter来计算元组的出现次数
    row_counts = Counter(row_tuples)

    # 初始化总的重复次数
    total_duplicate_count = 0

    # 创建一个集合来存储已经计数过的行
    counted_rows = set()

    # 打印重复行的行号（索引）和它们的重复次数，并计算总的重复次数
    for index, row in enumerate(Z):
        row_tuple = tuple(row)
        if row_tuple not in counted_rows:
            count = row_counts[row_tuple]
            if count > 1:
                duplicate_indices = [i for i, r in enumerate(Z) if tuple(r) == row_tuple]
                print(f"行 {index} 重复了 {count} 次，与行 {duplicate_indices} 重复")
                total_duplicate_count += count
            counted_rows.add(row_tuple)  # 将该行添加到已计数的行集合中

    # 打印总的重复次数
    print(f"总的重复次数为: {total_duplicate_count}")

    # 初始化总的不同重复行数
    total_unique_duplicate_count = 0

    # 创建一个集合来存储已经计数过的行
    counted_rows = set()

    # 计算不同的重复行数
    for row_tuple, count in row_counts.items():
        if count > 1:
            total_unique_duplicate_count += 1
            counted_rows.add(row_tuple)

    # 打印总的不同重复行数
    print(f"总的不同重复行数为: {total_unique_duplicate_count}")

# %%
import pandas as pd

folder_path = "original_data/"

merged_df = pd.read_csv(folder_path + 'Scaled_dataset.csv', encoding='utf-8', header=0)

columns = merged_df.columns


print(merged_df.shape)
# Out:
# (3960, 121)

# %% [markdown]
# # 去除芳基卤化物描述符

# %%
columns[19:46]
# Out:
# Index(['aryl_halide_.C1_NMR_shift', 'aryl_halide_.C1_electrostatic_charge',
#        'aryl_halide_.C2_NMR_shift', 'aryl_halide_.C2_electrostatic_charge',
#        'aryl_halide_.C3_NMR_shift', 'aryl_halide_.C3_electrostatic_charge',
#        'aryl_halide_.C4_NMR_shift', 'aryl_halide_.C4_electrostatic_charge',
#        'aryl_halide_.H2_NMR_shift', 'aryl_halide_.H2_electrostatic_charge',
#        'aryl_halide_.H3_NMR_shift', 'aryl_halide_.H3_electrostatic_charge',
#        'aryl_halide_E_HOMO', 'aryl_halide_E_LUMO', 'aryl_halide_V1_frequency',
#        'aryl_halide_V1_intensity', 'aryl_halide_V2_frequency',
#        'aryl_halide_V2_intensity', 'aryl_halide_V3_frequency',
#        'aryl_halide_V3_intensity', 'aryl_halide_dipole_moment',
#        'aryl_halide_electronegativity', 'aryl_halide_hardness',
#        'aryl_halide_molecular_volume', 'aryl_halide_molecular_weight',
#        'aryl_halide_ovality', 'aryl_halide_surface_area'],
#       dtype='object')

# %%
# 删除第20列到第46列   #去除芳香卤卤化物的描述符
columns_to_drop = merged_df.columns[19:46]  
merged_df = merged_df.drop(columns=columns_to_drop, axis=1)
print(merged_df.shape)
# Out:
# (3960, 94)

# %%
x_exp = merged_df.iloc[:, :-1].values  # 假设编号列是第0列，x列从第2列到倒数第二列
y_exp = merged_df.iloc[:, -1].values  # 最后一列作为y
print(x_exp.shape)
print(y_exp.shape)
# Out:
# (3960, 120)
# (3960,)

# %% [markdown]
# # 检查重复数据

# %%
find_duplicate_rows(x_exp)
# Out:
# 总的重复次数为: 0
# 总的不同重复行数为: 0

# %% [markdown]
# # 划分出芳基卤化物的X

# %%
x_exp_1 = x_exp[::15, :]
print(x_exp_1.shape)
# Out:
# (264, 93)

# %%
find_duplicate_rows(x_exp_1)
# Out:
# 总的重复次数为: 0
# 总的不同重复行数为: 0

# %% [markdown]
# # 对x进行minmax+pca+minmax

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

x_exp_mm = scaler.fit_transform(x_exp)
# x_exp_mm = scaler.fit_transform(x_exp_1)

# %%
from sklearn.decomposition import PCA

def PCA_dim_select(selected_method, n_dims):
    if selected_method == 'auto':
        assert type(n_dims) == float
        selected_dim = n_dims
    elif selected_method == 'assigned':
        # assert type(n_dims) == int
        selected_dim = int(n_dims)
    return selected_dim

pca_dims = 0.90
pca = PCA(n_components=PCA_dim_select('auto', pca_dims))

x_exp_mm_pca = pca.fit_transform(x_exp_mm)
print(x_exp_mm_pca.shape)
# Out:
# (3960, 9)

# %%
scaler1 = MinMaxScaler()
x_exp_mm_pca_mm = scaler1.fit_transform(x_exp_mm_pca)

# %% [markdown]
# # x与y合并为数据集

# %%
y_exp_1 = y_exp.reshape(-1,1)
print(y_exp_1.shape)
# Out:
# (3960, 1)

# %% [markdown]
# # 划分出各个卤化物的y

# %%
y_dict = {}
for i in range(0, 15):
    y_dict[f'y_{i}'] = y_exp_1[i::15, :]

# %%
max_value = np.max(y_dict['y_0'])
print(max_value)
# Out:
# 45.05

# %%
# 打印所有 y_i 的 shape
for key, value in y_dict.items():
    print(f"{key} 数据的形状：{value.shape}")
# Out:
# y_0 数据的形状：(264, 1)
# y_1 数据的形状：(264, 1)
# y_2 数据的形状：(264, 1)
# y_3 数据的形状：(264, 1)
# y_4 数据的形状：(264, 1)
# y_5 数据的形状：(264, 1)
# y_6 数据的形状：(264, 1)
# y_7 数据的形状：(264, 1)
# y_8 数据的形状：(264, 1)
# y_9 数据的形状：(264, 1)
# y_10 数据的形状：(264, 1)
# y_11 数据的形状：(264, 1)
# y_12 数据的形状：(264, 1)
# y_13 数据的形状：(264, 1)
# y_14 数据的形状：(264, 1)

# %%
# 循环保存
columns = [f'x{i+1}' for i in range(x_exp_mm_pca_mm.shape[1])]
x_df = pd.DataFrame(x_exp_mm_pca_mm, columns=columns)

for i in range(0, 15):
    y_df = pd.DataFrame(y_dict[f'y_{i}'], columns=['yield'])
    merged_data = pd.concat([x_df, y_df], axis=1)
    file_name = f'original_processed/aryl-{i+1}.xlsx'
    merged_data.to_excel(file_name, index=False)

print("所有文件已保存完毕。")
# Out:
# 所有文件已保存完毕。

# %% [markdown]
# # 保存单个数据

# %%
X_all = x_exp_mm_pca_mm
Y_all = y_exp_1

print(X_all.shape,Y_all.shape)
# Out:
# (3960, 9) (3960, 1)

# %%
#去除存在nan的点
nan_indices = np.isnan(Y_all)
true_indices = np.where(nan_indices)[0]
print("nan 的索引:", true_indices)

X_all = X_all[~nan_indices.flatten()]
Y_all = Y_all[~nan_indices.flatten()]

print(X_all.shape,Y_all.shape)
# Out:
# nan 的索引: [696 741 796 797 884]
# (3955, 9) (3955, 1)

# %%
# 单个保存
columns = [f'x{i+1}' for i in range(X_all.shape[1])]
x_df = pd.DataFrame(X_all, columns=columns)

y_df = pd.DataFrame(Y_all, columns=['yield'])

merged_data = pd.concat([x_df, y_df], axis=1)
merged_data.to_excel('original_processed/all_data.xlsx', index=False)

# %%
max_value = np.max(Y_all)
print(max_value)
# Out:
# 100.0

# %%
find_duplicate_rows(X_all)
find_duplicate_rows(Y_all)
# Out:
# 总的重复次数为: 0
# 总的不同重复行数为: 0
# 行 1 重复了 3 次，与行 [1, 2575, 3787] 重复
# 行 3 重复了 2 次，与行 [3, 87] 重复
# 行 8 重复了 2 次，与行 [8, 1493] 重复
# 行 9 重复了 2 次，与行 [9, 1087] 重复
# 行 11 重复了 3 次，与行 [11, 645, 2615] 重复
# 行 13 重复了 2 次，与行 [13, 1134] 重复
# 行 14 重复了 3 次，与行 [14, 1584, 3265] 重复
# 行 15 重复了 3 次，与行 [15, 1842, 3287] 重复
# 行 17 重复了 2 次，与行 [17, 3761] 重复
# 行 20 重复了 2 次，与行 [20, 851] 重复
# 行 21 重复了 2 次，与行 [21, 2011] 重复
# 行 22 重复了 2 次，与行 [22, 2460] 重复
# 行 27 重复了 2 次，与行 [27, 222] 重复
# 行 29 重复了 4 次，与行 [29, 600, 2414, 3602] 重复
# 行 31 重复了 2 次，与行 [31, 2675] 重复
# 行 33 重复了 6 次，与行 [33, 1048, 1828, 2656, 2713, 3688] 重复
# 行 34 重复了 2 次，与行 [34, 2698] 重复
# 行 39 重复了 2 次，与行 [39, 3387] 重复
# 行 44 重复了 2 次，与行 [44, 2185] 重复
# 行 45 重复了 2 次，与行 [45, 2692] 重复
# 行 48 重复了 236 次，与行 [48, 63, 78, 183, 198, 213, 288, 291, 306, 318, 333, 336, 348, 351, 396, 423, 468, 471, 483, 558, 573, 776, 777, 824, 827, 898, 913, 916, 958, 1033, 1135, 1138, 1139, 1141, 1147, 1150, 1153, 1154, 1156, 1162, 1180, 1228, 1231, 1243, 1318, 1321, 1327, 1333, 1336, 1342, 1408, 1453, 1468, 1495, 1498, 1507, 1513, 1522, 1528, 1588, 1597, 1618, 1633, 1663, 1675, 1678, 1681, 1687, 1693, 1696, 1702, 1708, 1753, 1768, 1771, 1777, 1795, 1797, 1798, 1799, 1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809, 1858, 1861, 1873, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1903, 1904, 1906, 1909, 1912, 1913, 1948, 1963, 1975, 1976, 1977, 1978, 1981, 1987, 1988, 2038, 2041, 2047, 2080, 2083, 2092, 2155, 2156, 2158, 2159, 2167, 2168, 2169, 2218, 2221, 2227, 2248, 2257, 2263, 2269, 2272, 2308, 2335, 2336, 2338, 2339, 2341, 2344, 2345, 2347, 2348, 2395, 2398, 2401, 2407, 2413, 2428, 2431, 2434, 2435, 2437, 2440, 2443, 2444, 2446, 2449, 2450, 2451, 2452, 2453, 2488, 2533, 2548, 2563, 2593, 2653, 2668, 2683, 2833, 2848, 2863, 2872, 2893, 2908, 2923, 2932, 2938, 2953, 3013, 3028, 3043, 3073, 3088, 3103, 3106, 3112, 3118, 3133, 3193, 3194, 3196, 3208, 3218, 3223, 3253, 3268, 3298, 3307, 3313, 3314, 3315, 3316, 3322, 3323, 3324, 3373, 3388, 3403, 3433, 3478, 3658, 3673, 3733, 3748, 3763, 3817, 3838, 3853, 3862, 3868, 3913, 3916, 3928, 3943] 重复
# 行 49 重复了 4 次，与行 [49, 427, 1779, 2628] 重复
# 行 51 重复了 4 次，与行 [51, 908, 1363, 2447] 重复
# 行 57 重复了 3 次，与行 [57, 420, 2404] 重复
# 行 60 重复了 3 次，与行 [60, 1449, 2602] 重复
# 行 64 重复了 3 次，与行 [64, 2213, 2397] 重复
# 行 66 重复了 8 次，与行 [66, 186, 1902, 2128, 2323, 2503, 3058, 3493] 重复
# 行 67 重复了 2 次，与行 [67, 2132] 重复
# 行 71 重复了 2 次，与行 [71, 2993] 重复
# 行 72 重复了 3 次，与行 [72, 651, 3730] 重复
# 行 81 重复了 5 次，与行 [81, 1901, 1993, 3100, 3946] 重复
# 行 91 重复了 2 次，与行 [91, 3276] 重复
# 行 92 重复了 3 次，与行 [92, 1839, 2939] 重复
# 行 93 重复了 2 次，与行 [93, 2416] 重复
# 行 95 重复了 2 次，与行 [95, 2479] 重复
# 行 96 重复了 2 次，与行 [96, 1694] 重复
# 行 101 重复了 2 次，与行 [101, 2667] 重复
# 行 105 重复了 2 次，与行 [105, 3273] 重复
# 行 108 重复了 2 次，与行 [108, 2686] 重复
# 行 109 重复了 2 次，与行 [109, 3779] 重复
# 行 110 重复了 2 次，与行 [110, 1781] 重复
# 行 112 重复了 2 次，与行 [112, 1785] 重复
# 行 114 重复了 2 次，与行 [114, 2576] 重复
# 行 119 重复了 2 次，与行 [119, 2712] 重复
# 行 121 重复了 3 次，与行 [121, 1092, 1145] 重复
# 行 122 重复了 3 次，与行 [122, 930, 1605] 重复
# 行 123 重复了 3 次，与行 [123, 1157, 3571] 重复
# 行 124 重复了 2 次，与行 [124, 1304] 重复
# 行 125 重复了 2 次，与行 [125, 3809] 重复
# 行 127 重复了 2 次，与行 [127, 497] 重复
# 行 129 重复了 2 次，与行 [129, 3701] 重复
# 行 131 重复了 2 次，与行 [131, 2732] 重复
# 行 133 重复了 2 次，与行 [133, 2694] 重复
# 行 135 重复了 2 次，与行 [135, 1761] 重复
# 行 137 重复了 2 次，与行 [137, 1915] 重复
# 行 138 重复了 3 次，与行 [138, 1441, 2274] 重复
# 行 139 重复了 2 次，与行 [139, 3191] 重复
# 行 145 重复了 2 次，与行 [145, 2967] 重复
# 行 146 重复了 2 次，与行 [146, 2847] 重复
# 行 149 重复了 2 次，与行 [149, 2126] 重复
# 行 150 重复了 2 次，与行 [150, 3427] 重复
# 行 153 重复了 2 次，与行 [153, 2551] 重复
# 行 156 重复了 3 次，与行 [156, 1983, 2448] 重复
# 行 157 重复了 2 次，与行 [157, 3150] 重复
# 行 159 重复了 2 次，与行 [159, 367] 重复
# 行 161 重复了 2 次，与行 [161, 742] 重复
# 行 162 重复了 2 次，与行 [162, 3791] 重复
# 行 164 重复了 2 次，与行 [164, 800] 重复
# 行 166 重复了 2 次，与行 [166, 1005] 重复
# 行 180 重复了 2 次，与行 [180, 2680] 重复
# 行 181 重复了 3 次，与行 [181, 752, 3122] 重复
# 行 187 重复了 2 次，与行 [187, 3152] 重复
# 行 189 重复了 3 次，与行 [189, 2178, 3000] 重复
# 行 190 重复了 2 次，与行 [190, 3574] 重复
# 行 192 重复了 3 次，与行 [192, 3405, 3865] 重复
# 行 195 重复了 2 次，与行 [195, 2340] 重复
# 行 196 重复了 2 次，与行 [196, 1343] 重复
# 行 201 重复了 5 次，与行 [201, 909, 1859, 1908, 3299] 重复
# 行 206 重复了 2 次，与行 [206, 700] 重复
# 行 211 重复了 2 次，与行 [211, 3653] 重复
# 行 214 重复了 2 次，与行 [214, 3135] 重复
# 行 216 重复了 4 次，与行 [216, 2264, 2836, 3796] 重复
# 行 226 重复了 3 次，与行 [226, 3087, 3554] 重复
# 行 229 重复了 2 次，与行 [229, 452] 重复
# 行 231 重复了 3 次，与行 [231, 2581, 3070] 重复
# 行 232 重复了 2 次，与行 [232, 3183] 重复
# 行 234 重复了 2 次，与行 [234, 3752] 重复
# 行 235 重复了 2 次，与行 [235, 370] 重复
# 行 242 重复了 4 次，与行 [242, 349, 2525, 3689] 重复
# 行 243 重复了 4 次，与行 [243, 1229, 1711, 3091] 重复
# 行 245 重复了 2 次，与行 [245, 512] 重复
# 行 246 重复了 2 次，与行 [246, 3925] 重复
# 行 248 重复了 2 次，与行 [248, 2931] 重复
# 行 258 重复了 3 次，与行 [258, 2113, 2536] 重复
# 行 261 重复了 4 次，与行 [261, 2026, 2557, 3397] 重复
# 行 270 重复了 2 次，与行 [270, 1582] 重复
# 行 272 重复了 2 次，与行 [272, 1720] 重复
# 行 273 重复了 2 次，与行 [273, 2342] 重复
# 行 274 重复了 2 次，与行 [274, 3599] 重复
# 行 276 重复了 2 次，与行 [276, 544] 重复
# 行 277 重复了 2 次，与行 [277, 2205] 重复
# 行 280 重复了 2 次，与行 [280, 1451] 重复
# 行 285 重复了 2 次，与行 [285, 797] 重复
# 行 286 重复了 2 次，与行 [286, 2002] 重复
# 行 290 重复了 2 次，与行 [290, 2861] 重复
# 行 298 重复了 2 次，与行 [298, 2987] 重复
# 行 299 重复了 2 次，与行 [299, 2929] 重复
# 行 301 重复了 2 次，与行 [301, 1455] 重复
# 行 303 重复了 3 次，与行 [303, 737, 1276] 重复
# 行 308 重复了 2 次，与行 [308, 389] 重复
# 行 313 重复了 2 次，与行 [313, 1386] 重复
# 行 315 重复了 2 次，与行 [315, 603] 重复
# 行 323 重复了 2 次，与行 [323, 3738] 重复
# 行 329 重复了 2 次，与行 [329, 1277] 重复
# 行 334 重复了 2 次，与行 [334, 1631] 重复
# 行 335 重复了 2 次，与行 [335, 3396] 重复
# 行 338 重复了 2 次，与行 [338, 2709] 重复
# 行 345 重复了 3 次，与行 [345, 1396, 3496] 重复
# 行 350 重复了 2 次，与行 [350, 2189] 重复
# 行 357 重复了 3 次，与行 [357, 707, 1417] 重复
# 行 358 重复了 2 次，与行 [358, 1566] 重复
# 行 360 重复了 2 次，与行 [360, 1814] 重复
# 行 361 重复了 2 次，与行 [361, 1729] 重复
# 行 363 重复了 4 次，与行 [363, 1438, 1690, 1796] 重复
# 行 366 重复了 7 次，与行 [366, 438, 809, 1003, 1288, 2266, 3556] 重复
# 行 371 重复了 2 次，与行 [371, 730] 重复
# 行 377 重复了 2 次，与行 [377, 2565] 重复
# 行 378 重复了 2 次，与行 [378, 928] 重复
# 行 393 重复了 3 次，与行 [393, 2383, 2866] 重复
# 行 395 重复了 3 次，与行 [395, 1709, 3410] 重复
# 行 405 重复了 2 次，与行 [405, 3466] 重复
# 行 408 重复了 3 次，与行 [408, 998, 3475] 重复
# 行 409 重复了 2 次，与行 [409, 1622] 重复
# 行 410 重复了 2 次，与行 [410, 3878] 重复
# 行 411 重复了 2 次，与行 [411, 2566] 重复
# 行 414 重复了 2 次，与行 [414, 1077] 重复
# 行 418 重复了 2 次，与行 [418, 2281] 重复
# 行 419 重复了 3 次，与行 [419, 590, 2394] 重复
# 行 425 重复了 2 次，与行 [425, 3446] 重复
# 行 426 重复了 2 次，与行 [426, 2188] 重复
# 行 429 重复了 2 次，与行 [429, 2921] 重复
# 行 435 重复了 2 次，与行 [435, 1864] 重复
# 行 436 重复了 2 次，与行 [436, 2812] 重复
# 行 439 重复了 3 次，与行 [439, 719, 3930] 重复
# 行 447 重复了 3 次，与行 [447, 1942, 3895] 重复
# 行 449 重复了 2 次，与行 [449, 1749] 重复
# 行 450 重复了 3 次，与行 [450, 2265, 3847] 重复
# 行 451 重复了 2 次，与行 [451, 3275] 重复
# 行 453 重复了 5 次，与行 [453, 1093, 1636, 1648, 3583] 重复
# 行 456 重复了 2 次，与行 [456, 722] 重复
# 行 460 重复了 2 次，与行 [460, 760] 重复
# 行 463 重复了 2 次，与行 [463, 2507] 重复
# 行 464 重复了 2 次，与行 [464, 2796] 重复
# 行 467 重复了 2 次，与行 [467, 3510] 重复
# 行 473 重复了 2 次，与行 [473, 3500] 重复
# 行 474 重复了 2 次，与行 [474, 1817] 重复
# 行 477 重复了 2 次，与行 [477, 2399] 重复
# 行 480 重复了 2 次，与行 [480, 3790] 重复
# 行 481 重复了 2 次，与行 [481, 3080] 重复
# 行 486 重复了 3 次，与行 [486, 1183, 2473] 重复
# 行 487 重复了 2 次，与行 [487, 1369] 重复
# 行 500 重复了 2 次，与行 [500, 3443] 重复
# 行 510 重复了 2 次，与行 [510, 596] 重复
# 行 513 重复了 3 次，与行 [513, 1273, 1723] 重复
# 行 514 重复了 2 次，与行 [514, 2697] 重复
# 行 515 重复了 2 次，与行 [515, 738] 重复
# 行 518 重复了 2 次，与行 [518, 1388] 重复
# 行 522 重复了 2 次，与行 [522, 3290] 重复
# 行 526 重复了 2 次，与行 [526, 1559] 重复
# 行 528 重复了 4 次，与行 [528, 1063, 1543, 2068] 重复
# 行 529 重复了 2 次，与行 [529, 3572] 重复
# 行 531 重复了 2 次，与行 [531, 3703] 重复
# 行 534 重复了 2 次，与行 [534, 3189] 重复
# 行 541 重复了 2 次，与行 [541, 1395] 重复
# 行 542 重复了 3 次，与行 [542, 1841, 3304] 重复
# 行 543 重复了 4 次，与行 [543, 943, 1447, 2143] 重复
# 行 545 重复了 3 次，与行 [545, 1958, 2641] 重复
# 行 547 重复了 3 次，与行 [547, 2129, 3472] 重复
# 行 548 重复了 2 次，与行 [548, 2606] 重复
# 行 550 重复了 3 次，与行 [550, 1112, 1624] 重复
# 行 551 重复了 3 次，与行 [551, 1263, 3340] 重复
# 行 556 重复了 3 次，与行 [556, 1612, 2603] 重复
# 行 559 重复了 3 次，与行 [559, 2518, 2920] 重复
# 行 560 重复了 3 次，与行 [560, 1214, 2271] 重复
# 行 561 重复了 2 次，与行 [561, 1905] 重复
# 行 562 重复了 3 次，与行 [562, 1837, 2670] 重复
# 行 564 重复了 2 次，与行 [564, 3467] 重复
# 行 568 重复了 2 次，与行 [568, 575] 重复
# 行 572 重复了 2 次，与行 [572, 1524] 重复
# 行 574 重复了 2 次，与行 [574, 1245] 重复
# 行 577 重复了 2 次，与行 [577, 3892] 重复
# 行 580 重复了 2 次，与行 [580, 3364] 重复
# 行 582 重复了 3 次，与行 [582, 940, 1210] 重复
# 行 584 重复了 3 次，与行 [584, 1409, 2894] 重复
# 行 585 重复了 3 次，与行 [585, 1980, 2426] 重复
# 行 586 重复了 3 次，与行 [586, 2087, 3682] 重复
# 行 588 重复了 2 次，与行 [588, 678] 重复
# 行 589 重复了 3 次，与行 [589, 810, 1840] 重复
# 行 591 重复了 2 次，与行 [591, 3309] 重复
# 行 606 重复了 2 次，与行 [606, 3270] 重复
# 行 608 重复了 2 次，与行 [608, 1793] 重复
# 行 610 重复了 2 次，与行 [610, 1055] 重复
# 行 613 重复了 2 次，与行 [613, 2981] 重复
# 行 618 重复了 3 次，与行 [618, 1051, 1666] 重复
# 行 624 重复了 3 次，与行 [624, 2520, 3119] 重复
# 行 631 重复了 2 次，与行 [631, 3430] 重复
# 行 633 重复了 3 次，与行 [633, 2878, 3793] 重复
# 行 634 重复了 2 次，与行 [634, 1587] 重复
# 行 636 重复了 2 次，与行 [636, 1080] 重复
# 行 637 重复了 2 次，与行 [637, 2123] 重复
# 行 640 重复了 2 次，与行 [640, 1604] 重复
# 行 641 重复了 3 次，与行 [641, 1090, 2242] 重复
# 行 648 重复了 2 次，与行 [648, 2173] 重复
# 行 661 重复了 3 次，与行 [661, 1422, 3889] 重复
# 行 663 重复了 2 次，与行 [663, 3553] 重复
# 行 666 重复了 3 次，与行 [666, 1615, 3463] 重复
# 行 668 重复了 2 次，与行 [668, 2819] 重复
# 行 672 重复了 4 次，与行 [672, 1105, 2534, 3319] 重复
# 行 682 重复了 2 次，与行 [682, 1884] 重复
# 行 683 重复了 2 次，与行 [683, 2166] 重复
# 行 684 重复了 2 次，与行 [684, 3687] 重复
# 行 685 重复了 4 次，与行 [685, 1410, 2906, 3932] 重复
# 行 686 重复了 2 次，与行 [686, 2940] 重复
# 行 693 重复了 4 次，与行 [693, 1573, 1756, 3931] 重复
# 行 694 重复了 3 次，与行 [694, 2139, 3509] 重复
# 行 696 重复了 2 次，与行 [696, 3560] 重复
# 行 698 重复了 2 次，与行 [698, 1353] 重复
# 行 701 重复了 2 次，与行 [701, 1606] 重复
# 行 702 重复了 2 次，与行 [702, 2873] 重复
# 行 708 重复了 3 次，与行 [708, 977, 1820] 重复
# 行 710 重复了 3 次，与行 [710, 2561, 3417] 重复
# 行 714 重复了 2 次，与行 [714, 939] 重复
# 行 715 重复了 2 次，与行 [715, 847] 重复
# 行 718 重复了 2 次，与行 [718, 935] 重复
# 行 723 重复了 2 次，与行 [723, 2600] 重复
# 行 724 重复了 2 次，与行 [724, 1019] 重复
# 行 725 重复了 2 次，与行 [725, 2684] 重复
# 行 731 重复了 2 次，与行 [731, 1083] 重复
# 行 732 重复了 3 次，与行 [732, 839, 2386] 重复
# 行 733 重复了 3 次，与行 [733, 1043, 1705] 重复
# 行 766 重复了 3 次，与行 [766, 2071, 2728] 重复
# 行 768 重复了 2 次，与行 [768, 975] 重复
# 行 772 重复了 2 次，与行 [772, 990] 重复
# 行 774 重复了 2 次，与行 [774, 2747] 重复
# 行 779 重复了 2 次，与行 [779, 3517] 重复
# 行 781 重复了 4 次，与行 [781, 2260, 2425, 3076] 重复
# 行 782 重复了 2 次，与行 [782, 2423] 重复
# 行 783 重复了 2 次，与行 [783, 3411] 重复
# 行 785 重复了 2 次，与行 [785, 2193] 重复
# 行 790 重复了 2 次，与行 [790, 2103] 重复
# 行 794 重复了 2 次，与行 [794, 3823] 重复
# 行 798 重复了 2 次，与行 [798, 933] 重复
# 行 799 重复了 2 次，与行 [799, 2739] 重复
# 行 803 重复了 2 次，与行 [803, 2621] 重复
# 行 812 重复了 2 次，与行 [812, 2890] 重复
# 行 813 重复了 2 次，与行 [813, 1823] 重复
# 行 818 重复了 2 次，与行 [818, 3332] 重复
# 行 822 重复了 2 次，与行 [822, 3381] 重复
# 行 823 重复了 2 次，与行 [823, 885] 重复
# 行 825 重复了 2 次，与行 [825, 1657] 重复
# 行 826 重复了 2 次，与行 [826, 3347] 重复
# 行 833 重复了 2 次，与行 [833, 1223] 重复
# 行 834 重复了 2 次，与行 [834, 3647] 重复
# 行 836 重复了 2 次，与行 [836, 3428] 重复
# 行 841 重复了 3 次，与行 [841, 1609, 2226] 重复
# 行 842 重复了 2 次，与行 [842, 2926] 重复
# 行 845 重复了 2 次，与行 [845, 2610] 重复
# 行 849 重复了 2 次，与行 [849, 1385] 重复
# 行 854 重复了 3 次，与行 [854, 1885, 2086] 重复
# 行 857 重复了 3 次，与行 [857, 1669, 2072] 重复
# 行 862 重复了 2 次，与行 [862, 1070] 重复
# 行 867 重复了 2 次，与行 [867, 1538] 重复
# 行 871 重复了 2 次，与行 [871, 2243] 重复
# 行 872 重复了 2 次，与行 [872, 2160] 重复
# 行 878 重复了 2 次，与行 [878, 1545] 重复
# 行 883 重复了 2 次，与行 [883, 3742] 重复
# 行 886 重复了 2 次，与行 [886, 1706] 重复
# 行 887 重复了 2 次，与行 [887, 1533] 重复
# 行 895 重复了 4 次，与行 [895, 2203, 2491, 3391] 重复
# 行 897 重复了 2 次，与行 [897, 2210] 重复
# 行 900 重复了 2 次，与行 [900, 3896] 重复
# 行 901 重复了 3 次，与行 [901, 1645, 2380] 重复
# 行 903 重复了 2 次，与行 [903, 3542] 重复
# 行 904 重复了 2 次，与行 [904, 2822] 重复
# 行 906 重复了 2 次，与行 [906, 1025] 重复
# 行 910 重复了 2 次，与行 [910, 1926] 重复
# 行 912 重复了 2 次，与行 [912, 1833] 重复
# 行 922 重复了 3 次，与行 [922, 944, 2387] 重复
# 行 931 重复了 2 次，与行 [931, 3766] 重复
# 行 941 重复了 2 次，与行 [941, 1095] 重复
# 行 946 重复了 2 次，与行 [946, 2626] 重复
# 行 951 重复了 2 次，与行 [951, 3424] 重复
# 行 955 重复了 2 次，与行 [955, 3526] 重复
# 行 965 重复了 2 次，与行 [965, 2225] 重复
# 行 967 重复了 2 次，与行 [967, 2941] 重复
# 行 971 重复了 2 次，与行 [971, 2354] 重复
# 行 973 重复了 2 次，与行 [973, 3637] 重复
# 行 976 重复了 2 次，与行 [976, 2439] 重复
# 行 982 重复了 2 次，与行 [982, 3786] 重复
# 行 984 重复了 2 次，与行 [984, 1389] 重复
# 行 985 重复了 2 次，与行 [985, 1874] 重复
# 行 986 重复了 2 次，与行 [986, 1027] 重复
# 行 988 重复了 3 次，与行 [988, 1030, 3436] 重复
# 行 991 重复了 2 次，与行 [991, 1882] 重复
# 行 993 重复了 2 次，与行 [993, 1564] 重复
# 行 999 重复了 2 次，与行 [999, 2085] 重复
# 行 1000 重复了 2 次，与行 [1000, 2597] 重复
# 行 1004 重复了 2 次，与行 [1004, 2954] 重复
# 行 1010 重复了 2 次，与行 [1010, 1652] 重复
# 行 1016 重复了 2 次，与行 [1016, 2598] 重复
# 行 1018 重复了 2 次，与行 [1018, 1660] 重复
# 行 1020 重复了 4 次，与行 [1020, 1115, 1650, 2640] 重复
# 行 1021 重复了 2 次，与行 [1021, 2082] 重复
# 行 1026 重复了 2 次，与行 [1026, 3186] 重复
# 行 1036 重复了 2 次，与行 [1036, 2441] 重复
# 行 1042 重复了 2 次，与行 [1042, 1762] 重复
# 行 1044 重复了 6 次，与行 [1044, 1672, 2035, 2084, 3586, 3598] 重复
# 行 1045 重复了 2 次，与行 [1045, 2665] 重复
# 行 1049 重复了 2 次，与行 [1049, 2745] 重复
# 行 1050 重复了 2 次，与行 [1050, 3514] 重复
# 行 1053 重复了 3 次，与行 [1053, 1058, 3636] 重复
# 行 1061 重复了 3 次，与行 [1061, 2420, 3720] 重复
# 行 1066 重复了 4 次，与行 [1066, 1303, 2445, 3022] 重复
# 行 1067 重复了 2 次，与行 [1067, 3504] 重复
# 行 1072 重复了 3 次，与行 [1072, 1240, 3595] 重复
# 行 1075 重复了 2 次，与行 [1075, 1854] 重复
# 行 1078 重复了 4 次，与行 [1078, 2273, 3538, 3802] 重复
# 行 1079 重复了 2 次，与行 [1079, 1496] 重复
# 行 1091 重复了 3 次，与行 [1091, 1444, 2492] 重复
# 行 1096 重复了 2 次，与行 [1096, 1769] 重复
# 行 1107 重复了 2 次，与行 [1107, 1725] 重复
# 行 1109 重复了 2 次，与行 [1109, 2131] 重复
# 行 1110 重复了 3 次，与行 [1110, 1959, 2206] 重复
# 行 1111 重复了 4 次，与行 [1111, 1238, 1855, 3238] 重复
# 行 1113 重复了 2 次，与行 [1113, 3505] 重复
# 行 1114 重复了 2 次，与行 [1114, 1193] 重复
# 行 1117 重复了 3 次，与行 [1117, 1492, 3148] 重复
# 行 1118 重复了 2 次，与行 [1118, 2543] 重复
# 行 1120 重复了 3 次，与行 [1120, 3190, 3310] 重复
# 行 1121 重复了 2 次，与行 [1121, 2685] 重复
# 行 1122 重复了 2 次，与行 [1122, 1125] 重复
# 行 1132 重复了 2 次，与行 [1132, 1957] 重复
# 行 1136 重复了 3 次，与行 [1136, 1862, 3277] 重复
# 行 1140 重复了 2 次，与行 [1140, 3871] 重复
# 行 1142 重复了 2 次，与行 [1142, 3898] 重复
# 行 1143 重复了 3 次，与行 [1143, 1232, 2430] 重复
# 行 1144 重复了 2 次，与行 [1144, 1423] 重复
# 行 1149 重复了 2 次，与行 [1149, 3494] 重复
# 行 1151 重复了 2 次，与行 [1151, 1163] 重复
# 行 1155 重复了 2 次，与行 [1155, 3406] 重复
# 行 1158 重复了 2 次，与行 [1158, 3877] 重复
# 行 1164 重复了 2 次，与行 [1164, 1546] 重复
# 行 1167 重复了 2 次，与行 [1167, 3567] 重复
# 行 1178 重复了 2 次，与行 [1178, 2137] 重复
# 行 1182 重复了 2 次，与行 [1182, 2017] 重复
# 行 1186 重复了 2 次，与行 [1186, 1843] 重复
# 行 1188 重复了 2 次，与行 [1188, 3749] 重复
# 行 1195 重复了 2 次，与行 [1195, 1523] 重复
# 行 1197 重复了 3 次，与行 [1197, 2730, 3059] 重复
# 行 1198 重复了 2 次，与行 [1198, 2578] 重复
# 行 1200 重复了 2 次，与行 [1200, 3604] 重复
# 行 1201 重复了 2 次，与行 [1201, 3254] 重复
# 行 1204 重复了 2 次，与行 [1204, 2288] 重复
# 行 1208 重复了 2 次，与行 [1208, 2291] 重复
# 行 1213 重复了 2 次，与行 [1213, 3217] 重复
# 行 1215 重复了 2 次，与行 [1215, 1766] 重复
# 行 1219 重复了 2 次，与行 [1219, 2875] 重复
# 行 1220 重复了 2 次，与行 [1220, 1856] 重复
# 行 1225 重复了 2 次，与行 [1225, 3130] 重复
# 行 1230 重复了 3 次，与行 [1230, 1450, 1816] 重复
# 行 1233 重复了 2 次，与行 [1233, 2654] 重复
# 行 1239 重复了 3 次，与行 [1239, 1685, 2408] 重复
# 行 1244 重复了 2 次，与行 [1244, 2902] 重复
# 行 1247 重复了 2 次，与行 [1247, 1778] 重复
# 行 1248 重复了 2 次，与行 [1248, 3502] 重复
# 行 1250 重复了 2 次，与行 [1250, 3911] 重复
# 行 1256 重复了 2 次，与行 [1256, 2197] 重复
# 行 1257 重复了 3 次，与行 [1257, 1925, 3289] 重复
# 行 1258 重复了 2 次，与行 [1258, 3181] 重复
# 行 1259 重复了 2 次，与行 [1259, 3245] 重复
# 行 1261 重复了 3 次，与行 [1261, 1480, 3448] 重复
# 行 1265 重复了 2 次，与行 [1265, 2652] 重复
# 行 1269 重复了 2 次，与行 [1269, 2220] 重复
# 行 1272 重复了 2 次，与行 [1272, 1542] 重复
# 行 1274 重复了 2 次，与行 [1274, 3116] 重复
# 行 1282 重复了 2 次，与行 [1282, 2256] 重复
# 行 1294 重复了 2 次，与行 [1294, 3138] 重复
# 行 1299 重复了 2 次，与行 [1299, 1746] 重复
# 行 1302 重复了 2 次，与行 [1302, 3385] 重复
# 行 1308 重复了 3 次，与行 [1308, 3235, 3646] 重复
# 行 1309 重复了 2 次，与行 [1309, 2679] 重复
# 行 1312 重复了 2 次，与行 [1312, 2337] 重复
# 行 1313 重复了 3 次，与行 [1313, 1758, 2042] 重复
# 行 1314 重复了 2 次，与行 [1314, 3296] 重复
# 行 1315 重复了 2 次，与行 [1315, 3613] 重复
# 行 1319 重复了 2 次，与行 [1319, 2512] 重复
# 行 1322 重复了 3 次，与行 [1322, 1956, 2635] 重复
# 行 1323 重复了 2 次，与行 [1323, 2634] 重复
# 行 1330 重复了 2 次，与行 [1330, 1918] 重复
# 行 1334 重复了 2 次，与行 [1334, 1945] 重复
# 行 1339 重复了 2 次，与行 [1339, 1420] 重复
# 行 1345 重复了 3 次，与行 [1345, 2558, 3326] 重复
# 行 1347 重复了 2 次，与行 [1347, 3227] 重复
# 行 1352 重复了 2 次，与行 [1352, 3739] 重复
# 行 1362 重复了 3 次，与行 [1362, 2577, 3348] 重复
# 行 1364 重复了 2 次，与行 [1364, 3015] 重复
# 行 1365 重复了 3 次，与行 [1365, 2481, 2630] 重复
# 行 1370 重复了 2 次，与行 [1370, 2789] 重复
# 行 1372 重复了 2 次，与行 [1372, 3644] 重复
# 行 1376 重复了 2 次，与行 [1376, 3477] 重复
# 行 1377 重复了 2 次，与行 [1377, 1827] 重复
# 行 1378 重复了 2 次，与行 [1378, 2454] 重复
# 行 1390 重复了 2 次，与行 [1390, 2542] 重复
# 行 1394 重复了 2 次，与行 [1394, 1844] 重复
# 行 1397 重复了 3 次，与行 [1397, 2614, 3490] 重复
# 行 1405 重复了 2 次，与行 [1405, 3046] 重复
# 行 1407 重复了 2 次，与行 [1407, 2108] 重复
# 行 1416 重复了 2 次，与行 [1416, 2804] 重复
# 行 1421 重复了 2 次，与行 [1421, 3399] 重复
# 行 1429 重复了 2 次，与行 [1429, 2421] 重复
# 行 1435 重复了 2 次，与行 [1435, 2662] 重复
# 行 1439 重复了 2 次，与行 [1439, 2746] 重复
# 行 1442 重复了 2 次，与行 [1442, 1490] 重复
# 行 1445 重复了 2 次，与行 [1445, 1607] 重复
# 行 1457 重复了 2 次，与行 [1457, 2592] 重复
# 行 1460 重复了 2 次，与行 [1460, 3047] 重复
# 行 1462 重复了 5 次，与行 [1462, 1501, 1684, 1863, 2896] 重复
# 行 1464 重复了 2 次，与行 [1464, 3531] 重复
# 行 1465 重复了 2 次，与行 [1465, 1682] 重复
# 行 1477 重复了 2 次，与行 [1477, 3706] 重复
# 行 1482 重复了 2 次，与行 [1482, 3511] 重复
# 行 1486 重复了 2 次，与行 [1486, 3523] 重复
# 行 1494 重复了 3 次，与行 [1494, 1846, 2024] 重复
# 行 1499 重复了 3 次，与行 [1499, 3085, 3308] 重复
# 行 1502 重复了 3 次，与行 [1502, 3241, 3367] 重复
# 行 1504 重复了 3 次，与行 [1504, 1934, 2251] 重复
# 行 1509 重复了 2 次，与行 [1509, 3244] 重复
# 行 1510 重复了 2 次，与行 [1510, 2353] 重复
# 行 1511 重复了 2 次，与行 [1511, 3359] 重复
# 行 1517 重复了 2 次，与行 [1517, 1579] 重复
# 行 1530 重复了 2 次，与行 [1530, 2059] 重复
# 行 1539 重复了 2 次，与行 [1539, 2704] 重复
# 行 1550 重复了 2 次，与行 [1550, 2556] 重复
# 行 1557 重复了 3 次，与行 [1557, 3081, 3449] 重复
# 行 1558 重复了 5 次，与行 [1558, 1738, 2429, 3211, 3226] 重复
# 行 1561 重复了 2 次，与行 [1561, 3592] 重复
# 行 1563 重复了 2 次，与行 [1563, 1716] 重复
# 行 1565 重复了 2 次，与行 [1565, 2379] 重复
# 行 1570 重复了 3 次，与行 [1570, 1691, 2461] 重复
# 行 1571 重复了 3 次，与行 [1571, 2073, 3282] 重复
# 行 1572 重复了 2 次，与行 [1572, 2382] 重复
# 行 1576 重复了 2 次，与行 [1576, 2249] 重复
# 行 1585 重复了 2 次，与行 [1585, 3202] 重复
# 行 1589 重复了 2 次，与行 [1589, 1919] 重复
# 行 1592 重复了 2 次，与行 [1592, 2163] 重复
# 行 1595 重复了 2 次，与行 [1595, 2539] 重复
# 行 1608 重复了 2 次，与行 [1608, 2798] 重复
# 行 1617 重复了 3 次，与行 [1617, 1750, 2074] 重复
# 行 1620 重复了 2 次，与行 [1620, 3331] 重复
# 行 1626 重复了 2 次，与行 [1626, 2411] 重复
# 行 1628 重复了 2 次，与行 [1628, 3031] 重复
# 行 1635 重复了 2 次，与行 [1635, 3569] 重复
# 行 1637 重复了 2 次，与行 [1637, 2111] 重复
# 行 1640 重复了 2 次，与行 [1640, 3395] 重复
# 行 1647 重复了 2 次，与行 [1647, 3675] 重复
# 行 1651 重复了 2 次，与行 [1651, 3301] 重复
# 行 1653 重复了 2 次，与行 [1653, 2153] 重复
# 行 1654 重复了 2 次，与行 [1654, 2568] 重复
# 行 1664 重复了 2 次，与行 [1664, 3317] 重复
# 行 1670 重复了 2 次，与行 [1670, 3016] 重复
# 行 1673 重复了 2 次，与行 [1673, 3346] 重复
# 行 1679 重复了 2 次，与行 [1679, 2476] 重复
# 行 1680 重复了 2 次，与行 [1680, 3055] 重复
# 行 1686 重复了 2 次，与行 [1686, 3259] 重复
# 行 1689 重复了 3 次，与行 [1689, 1775, 3370] 重复
# 行 1697 重复了 2 次，与行 [1697, 3775] 重复
# 行 1698 重复了 2 次，与行 [1698, 3563] 重复
# 行 1712 重复了 2 次，与行 [1712, 3036] 重复
# 行 1715 重复了 2 次，与行 [1715, 2930] 重复
# 行 1717 重复了 2 次，与行 [1717, 3481] 重复
# 行 1724 重复了 2 次，与行 [1724, 3012] 重复
# 行 1726 重复了 2 次，与行 [1726, 2743] 重复
# 行 1730 重复了 2 次，与行 [1730, 2332] 重复
# 行 1736 重复了 3 次，与行 [1736, 2760, 3124] 重复
# 行 1755 重复了 2 次，与行 [1755, 3281] 重复
# 行 1764 重复了 2 次，与行 [1764, 2201] 重复
# 行 1765 重复了 2 次，与行 [1765, 1813] 重复
# 行 1770 重复了 2 次，与行 [1770, 2659] 重复
# 行 1776 重复了 2 次，与行 [1776, 3640] 重复
# 行 1786 重复了 3 次，与行 [1786, 2267, 3269] 重复
# 行 1787 重复了 2 次，与行 [1787, 1789] 重复
# 行 1791 重复了 2 次，与行 [1791, 3021] 重复
# 行 1810 重复了 2 次，与行 [1810, 2409] 重复
# 行 1811 重复了 3 次，与行 [1811, 1931, 2589] 重复
# 行 1812 重复了 2 次，与行 [1812, 2711] 重复
# 行 1831 重复了 2 次，与行 [1831, 2078] 重复
# 行 1832 重复了 2 次，与行 [1832, 3320] 重复
# 行 1836 重复了 2 次，与行 [1836, 3164] 重复
# 行 1848 重复了 2 次，与行 [1848, 1849] 重复
# 行 1850 重复了 2 次，与行 [1850, 3334] 重复
# 行 1866 重复了 2 次，与行 [1866, 1923] 重复
# 行 1868 重复了 3 次，与行 [1868, 2215, 3883] 重复
# 行 1872 重复了 2 次，与行 [1872, 2490] 重复
# 行 1876 重复了 2 次，与行 [1876, 1911] 重复
# 行 1910 重复了 3 次，与行 [1910, 2731, 3952] 重复
# 行 1916 重复了 2 次，与行 [1916, 2595] 重复
# 行 1920 重复了 2 次，与行 [1920, 2590] 重复
# 行 1930 重复了 2 次，与行 [1930, 2349] 重复
# 行 1933 重复了 2 次，与行 [1933, 2233] 重复
# 行 1946 重复了 2 次，与行 [1946, 2028] 重复
# 行 1951 重复了 2 次，与行 [1951, 3940] 重复
# 行 1964 重复了 2 次，与行 [1964, 2081] 重复
# 行 1965 重复了 4 次，与行 [1965, 2261, 3271, 3343] 重复
# 行 1992 重复了 3 次，与行 [1992, 2891, 2933] 重复
# 行 1996 重复了 3 次，与行 [1996, 2255, 3052] 重复
# 行 2005 重复了 2 次，与行 [2005, 2102] 重复
# 行 2008 重复了 2 次，与行 [2008, 2758] 重复
# 行 2021 重复了 2 次，与行 [2021, 2305] 重复
# 行 2027 重复了 2 次，与行 [2027, 2571] 重复
# 行 2032 重复了 2 次，与行 [2032, 2632] 重复
# 行 2039 重复了 2 次，与行 [2039, 3577] 重复
# 行 2045 重复了 2 次，与行 [2045, 3927] 重复
# 行 2058 重复了 2 次，与行 [2058, 3233] 重复
# 行 2062 重复了 2 次，与行 [2062, 3492] 重复
# 行 2065 重复了 2 次，与行 [2065, 3856] 重复
# 行 2069 重复了 2 次，与行 [2069, 3145] 重复
# 行 2076 重复了 2 次，与行 [2076, 2253] 重复
# 行 2077 重复了 2 次，与行 [2077, 2432] 重复
# 行 2088 重复了 2 次，与行 [2088, 2258] 重复
# 行 2089 重复了 2 次，与行 [2089, 3616] 重复
# 行 2099 重复了 2 次，与行 [2099, 3101] 重复
# 行 2122 重复了 2 次，与行 [2122, 3521] 重复
# 行 2133 重复了 2 次，与行 [2133, 3372] 重复
# 行 2141 重复了 2 次，与行 [2141, 2524] 重复
# 行 2142 重复了 2 次，与行 [2142, 2625] 重复
# 行 2144 重复了 3 次，与行 [2144, 2174, 2755] 重复
# 行 2146 重复了 2 次，与行 [2146, 3250] 重复
# 行 2170 重复了 2 次，与行 [2170, 3236] 重复
# 行 2182 重复了 2 次，与行 [2182, 2467] 重复
# 行 2211 重复了 2 次，与行 [2211, 3837] 重复
# 行 2216 重复了 2 次，与行 [2216, 3476] 重复
# 行 2223 重复了 2 次，与行 [2223, 3075] 重复
# 行 2245 重复了 3 次，与行 [2245, 2371, 3718] 重复
# 行 2268 重复了 2 次，与行 [2268, 3760] 重复
# 行 2275 重复了 2 次，与行 [2275, 3611] 重复
# 行 2277 重复了 2 次，与行 [2277, 2546] 重复
# 行 2278 重复了 3 次，与行 [2278, 2368, 3136] 重复
# 行 2282 重复了 2 次，与行 [2282, 3147] 重复
# 行 2286 重复了 2 次，与行 [2286, 3915] 重复
# 行 2290 重复了 2 次，与行 [2290, 3780] 重复
# 行 2292 重复了 2 次，与行 [2292, 3831] 重复
# 行 2296 重复了 2 次，与行 [2296, 2655] 重复
# 行 2310 重复了 2 次，与行 [2310, 2663] 重复
# 行 2311 重复了 2 次，与行 [2311, 2381] 重复
# 行 2356 重复了 2 次，与行 [2356, 3910] 重复
# 行 2372 重复了 2 次，与行 [2372, 2844] 重复
# 行 2406 重复了 2 次，与行 [2406, 3344] 重复
# 行 2438 重复了 3 次，与行 [2438, 3166, 3262] 重复
# 行 2442 重复了 2 次，与行 [2442, 3256] 重复
# 行 2469 重复了 2 次，与行 [2469, 2936] 重复
# 行 2474 重复了 2 次，与行 [2474, 2482] 重复
# 行 2475 重复了 2 次，与行 [2475, 2664] 重复
# 行 2477 重复了 2 次，与行 [2477, 3863] 重复
# 行 2493 重复了 2 次，与行 [2493, 2816] 重复
# 行 2501 重复了 2 次，与行 [2501, 3353] 重复
# 行 2502 重复了 2 次，与行 [2502, 2624] 重复
# 行 2509 重复了 2 次，与行 [2509, 3714] 重复
# 行 2530 重复了 2 次，与行 [2530, 3608] 重复
# 行 2553 重复了 2 次，与行 [2553, 3083] 重复
# 行 2555 重复了 2 次，与行 [2555, 3719] 重复
# 行 2570 重复了 2 次，与行 [2570, 3312] 重复
# 行 2585 重复了 2 次，与行 [2585, 3507] 重复
# 行 2594 重复了 2 次，与行 [2594, 3907] 重复
# 行 2608 重复了 2 次，与行 [2608, 2618] 重复
# 行 2611 重复了 2 次，与行 [2611, 3291] 重复
# 行 2612 重复了 2 次，与行 [2612, 3920] 重复
# 行 2616 重复了 3 次，与行 [2616, 2633, 3866] 重复
# 行 2617 重复了 2 次，与行 [2617, 3393] 重复
# 行 2627 重复了 2 次，与行 [2627, 2648] 重复
# 行 2671 重复了 2 次，与行 [2671, 3811] 重复
# 行 2674 重复了 2 次，与行 [2674, 3175] 重复
# 行 2688 重复了 2 次，与行 [2688, 3552] 重复
# 行 2706 重复了 2 次，与行 [2706, 3633] 重复
# 行 2721 重复了 2 次，与行 [2721, 3654] 重复
# 行 2727 重复了 3 次，与行 [2727, 2862, 3585] 重复
# 行 2742 重复了 2 次，与行 [2742, 2879] 重复
# 行 2748 重复了 2 次，与行 [2748, 3529] 重复
# 行 2757 重复了 2 次，与行 [2757, 2786] 重复
# 行 2763 重复了 2 次，与行 [2763, 3062] 重复
# 行 2764 重复了 2 次，与行 [2764, 3512] 重复
# 行 2773 重复了 2 次，与行 [2773, 3778] 重复
# 行 2781 重复了 2 次，与行 [2781, 2825] 重复
# 行 2783 重复了 2 次，与行 [2783, 3819] 重复
# 行 2788 重复了 2 次，与行 [2788, 2947] 重复
# 行 2790 重复了 2 次，与行 [2790, 3017] 重复
# 行 2801 重复了 2 次，与行 [2801, 3581] 重复
# 行 2802 重复了 2 次，与行 [2802, 3077] 重复
# 行 2810 重复了 2 次，与行 [2810, 2988] 重复
# 行 2827 重复了 2 次，与行 [2827, 3132] 重复
# 行 2852 重复了 2 次，与行 [2852, 3660] 重复
# 行 2853 重复了 2 次，与行 [2853, 3438] 重复
# 行 2887 重复了 2 次，与行 [2887, 3676] 重复
# 行 2895 重复了 2 次，与行 [2895, 3623] 重复
# 行 2913 重复了 2 次，与行 [2913, 2958] 重复
# 行 2917 重复了 2 次，与行 [2917, 3151] 重复
# 行 2952 重复了 3 次，与行 [2952, 3042, 3488] 重复
# 行 2960 重复了 2 次，与行 [2960, 3005] 重复
# 行 2969 重复了 2 次，与行 [2969, 3933] 重复
# 行 2974 重复了 2 次，与行 [2974, 3694] 重复
# 行 2994 重复了 2 次，与行 [2994, 3200] 重复
# 行 3001 重复了 2 次，与行 [3001, 3352] 重复
# 行 3014 重复了 2 次，与行 [3014, 3716] 重复
# 行 3018 重复了 2 次，与行 [3018, 3558] 重复
# 行 3029 重复了 2 次，与行 [3029, 3881] 重复
# 行 3030 重复了 2 次，与行 [3030, 3203] 重复
# 行 3037 重复了 2 次，与行 [3037, 3382] 重复
# 行 3089 重复了 2 次，与行 [3089, 3606] 重复
# 行 3125 重复了 2 次，与行 [3125, 3134] 重复
# 行 3144 重复了 2 次，与行 [3144, 3456] 重复
# 行 3157 重复了 2 次，与行 [3157, 3318] 重复
# 行 3158 重复了 2 次，与行 [3158, 3325] 重复
# 行 3163 重复了 2 次，与行 [3163, 3537] 重复
# 行 3188 重复了 2 次，与行 [3188, 3548] 重复
# 行 3213 重复了 2 次，与行 [3213, 3713] 重复
# 行 3249 重复了 2 次，与行 [3249, 3670] 重复
# 行 3305 重复了 2 次，与行 [3305, 3402] 重复
# 行 3337 重复了 2 次，与行 [3337, 3357] 重复
# 行 3338 重复了 2 次，与行 [3338, 3617] 重复
# 行 3362 重复了 2 次，与行 [3362, 3926] 重复
# 行 3369 重复了 2 次，与行 [3369, 3627] 重复
# 行 3376 重复了 3 次，与行 [3376, 3628, 3643] 重复
# 行 3524 重复了 2 次，与行 [3524, 3536] 重复
# 行 3575 重复了 2 次，与行 [3575, 3711] 重复
# 行 3717 重复了 2 次，与行 [3717, 3734] 重复
# 行 3725 重复了 2 次，与行 [3725, 3729] 重复
# 行 3860 重复了 2 次，与行 [3860, 3885] 重复
# 总的重复次数为: 1689
# 总的不同重复行数为: 636
